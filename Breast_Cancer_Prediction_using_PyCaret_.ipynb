# %%
#import libraryies
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Read data
data = pd.read_csv('/content/BRCA Data.csv')
data.head()
# Out:
#      Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
#
#   Tumour_Stage                      Histology ER status PR status HER2 status  \
# 0          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1           II             Mucinous Carcinoma  Positive  Positive    Negative
# 2          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 4           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                   Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# ...

# %%
#check Null valu on data
data.isnull().any()
# Out:
# Patient_ID            True
# Age                   True
# Gender                True
# Protein1              True
# Protein2              True
# Protein3              True
# Protein4              True
# Tumour_Stage          True
# Histology             True
# ER status             True
# PR status             True
# HER2 status           True
# Surgery_type          True
# Date_of_Surgery       True
# Date_of_Last_Visit    True
# Patient_Status        True
# dtype: bool

# %%
#check null value and summerize
data.isnull().sum()
# Out:
# Patient_ID             7
# Age                    7
# Gender                 7
# Protein1               7
# Protein2               7
# Protein3               7
# Protein4               7
# Tumour_Stage           7
# Histology              7
# ER status              7
# PR status              7
# HER2 status            7
# Surgery_type           7
# Date_of_Surgery        7
# Date_of_Last_Visit    24
# Patient_Status        20
# dtype: int64

# %%
#drop null value
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Patient_ID            0
# Age                   0
# Gender                0
# Protein1              0
# Protein2              0
# Protein3              0
# Protein4              0
# Tumour_Stage          0
# Histology             0
# ER status             0
# PR status             0
# HER2 status           0
# Surgery_type          0
# Date_of_Surgery       0
# Date_of_Last_Visit    0
# Patient_Status        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 333
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          317 non-null    object
#  1   Age                 317 non-null    float64
#  2   Gender              317 non-null    object
#  3   Protein1            317 non-null    float64
#  4   Protein2            317 non-null    float64
#  5   Protein3            317 non-null    float64
#  6   Protein4            317 non-null    float64
#  7   Tumour_Stage        317 non-null    object
#  8   Histology           317 non-null    object
#  9   ER status           317 non-null    object
#  10  PR status           317 non-null    object
#  11  HER2 status         317 non-null    object
#  12  Surgery_type        317 non-null    object
#  13  Date_of_Surgery     317 non-null    object
#  14  Date_of_Last_Visit  317 non-null    object
# ...

# %%
data.Gender.value_counts() # highly imblacne data set
# Out:
# FEMALE    313
# MALE        4
# Name: Gender, dtype: int64

# %%
data.Patient_Status.value_counts()*100/len(data)
# Out:
# Alive    80.44164
# Dead     19.55836
# Name: Patient_Status, dtype: float64

# %%
#Vizualization Patient_Status
from sqlalchemy.engine.base import Transaction
Patient_Status = data['Patient_Status'].value_counts()
Transaction = Patient_Status.index
quantity = Patient_Status.values
figure = px.pie(data,values=quantity,names=Transaction,hole=0.5,title="Patient_Status")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#vizualization of Tumour Stage
Tumour_Stage = data['Tumour_Stage'].value_counts()
Transaction = Tumour_Stage.index
quantity = Tumour_Stage.values
figure = px.pie(data,values=quantity,names=Transaction,hole=0.5,title="Tumour_Stage of Patient")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Vizalization of Histology
Histology = data['Histology'].value_counts()
Transaction = Histology.index
quantity = Histology.values
figure = px.pie(data,values=quantity,names=Transaction,hole=0.5,title="Histology of Patient")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Vizualilzation of ER status
ER_status = data['ER status'].value_counts()
Transaction = ER_status.index
quantity = ER_status.values
figure = px.pie(data,values=quantity,names=Transaction,hole=0.5,title="ER status of Patient")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Vizualization of PR Status
PR_status = data['PR status'].value_counts()
Transaction = PR_status.index
quantity = PR_status.values
figure = px.pie(data,values=quantity,names=Transaction,hole=0.5,title="PR status of Patient")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Vizualization of PR Status
HER2_status = data['HER2 status'].value_counts()
Transaction = PR_status.index
quantity = PR_status.values
figure = px.pie(data,values=quantity,names=Transaction,hole=0.5,title=" status of Patient")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.drop(['Patient_ID','ER status','PR status','Date_of_Surgery','Date_of_Last_Visit'],axis=1,inplace=True)

# %%
# !pip install pycaret

# %%
# !pip install mlflow

# %%
from pycaret.classification import *

# %%
cancer = setup(data = data, target = 'Patient_Status',
                  normalize = True,
                  transformation = True,
                  log_experiment = True,
                  remove_multicollinearity = True, #Drop one of the two features that are highly correlated with each other
                  numeric_imputation='median',
                  fold = 5,
                  #ignore_features=['Patient_ID'],
                  #date_features=['Date_of_Surgery','Date_of_Last_Visit'],
                  #fix_imbalance = False,
                  train_size = 0.70
          )
# Out:
# <style type="text/css">
# #T_ff2e4_row11_col1, #T_ff2e4_row17_col1, #T_ff2e4_row19_col1, #T_ff2e4_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ff2e4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff2e4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ff2e4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff2e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff2e4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ff2e4_row0_col1" class="data row0 col1" >4054</td>
#     </tr>
#     <tr>
#       <th id="T_ff2e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff2e4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ff2e4_row1_col1" class="data row1 col1" >Patient_Status</td>
#     </tr>
#     <tr>
# ...

# %%
Random_forest = create_model('rf')
# Out:
# <style type="text/css">
# #T_62617_row5_col0, #T_62617_row5_col1, #T_62617_row5_col2, #T_62617_row5_col3, #T_62617_row5_col4, #T_62617_row5_col5, #T_62617_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_62617" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62617_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_62617_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_62617_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_62617_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_62617_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_62617_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_62617_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# check all available config
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
get_config('y_transformed')
# Out:
# 291    0
# 4      1
# 271    0
# 301    0
# 297    0
#       ..
# 79     1
# 212    0
# 231    0
# 57     0
# 275    0
# Name: Patient_Status, Length: 317, dtype: int64

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_162af th {
#   text-align: left;
# }
# ...

# %%
dummy = create_model('dummy')
# Out:
# <style type="text/css">
# #T_98164_row5_col0, #T_98164_row5_col1, #T_98164_row5_col2, #T_98164_row5_col3, #T_98164_row5_col4, #T_98164_row5_col5, #T_98164_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_98164" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98164_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_98164_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_98164_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_98164_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_98164_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_98164_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_98164_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(dummy)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model('ridge')
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
unseen_predictions = predict_model(dummy, data = data)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_96f18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96f18_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_96f18_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_96f18_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_96f18_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_96f18_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_96f18_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_96f18_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_96f18_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96f18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96f18_row0_col0" class="data row0 col0" >Dummy Classifier</td>
# ...

# %%
save_model(dummy,'model_dummy')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Protein1', 'Protein2',
#                                               'Protein3', 'Protein4'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_featur...
#                  ('normalize',
#                   TransformerWrapper(exclude=None, include=None,
# ...
